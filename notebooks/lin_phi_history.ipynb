# %%
from bokeh.plotting import figure
from bokeh.layouts import row, column
from bokeh.io import output_notebook, show
from bokeh.models import ColorBar, ColumnDataSource, LinearColorMapper,LogColorMapper,HoverTool,Label 
from scipy import optimize, row_stack, empty_like, empty, newaxis
import scipy.odr as odr
import numpy as np
def make_histo(p, hist, edges, color="deepskyblue",legend_label=''):
    # example call:
    #
    # measured = np.random.normal(mu, sigma, 1000)
    # hist, edges = np.histogram(measured, density=True, bins=50)
    # p1 = make_plot("Histohgram", hist, edges)

    #p = figure(title=title, tools='', background_fill_color="#fafafa")
    p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
           fill_color=color, line_color="white", alpha=0.5,legend_label=legend_label)
    p.y_range.start = 0
    p.legend.background_fill_color = "#fefefe"
    p.grid.grid_line_color="linen"
    return p

def add_histo(p, hist, edges, color='purple',legend_label=''):
    #p = figure(title=title, tools='', background_fill_color="#fafafa")
    p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
           fill_color=color, line_color="white", alpha=0.5,legend_label=legend_label)
    #p.y_range.start = 0
    #p.legend.background_fill_color = "#fefefe"
    #p.grid.grid_line_color="linen"
    return p
def pretty_plot(p,xlabel='',ylabel=''):

    #title = title
    #p = figure(title=title, background_fill_color="#fafafa",tools=tools) #, y_range=(0, 10.5))

    p.xaxis.axis_label=xlabel
    p.yaxis.axis_label=ylabel
    p.xaxis.axis_label_text_font_size = '12pt'
    p.yaxis.axis_label_text_font_size = '12pt'
    p.xaxis.major_label_text_font_size = '12pt'
    p.yaxis.major_label_text_font_size = '12pt'
    p.title.text_font_size = '12pt'
    
    return p
def plot_scatter(p):
    p.circle(dn,sn,fill_color='purple',size=4.,fill_alpha=0.9,line_color=None)

 
def RMS(x):
    square = 0
    mean = 0.0
    root = 0.0
     
    #Calculate square
    square = sum([i**2 for i in x])
    #Calculate Mean
    mean = square / float(len(x))
     
    #Calculate Root
    return np.sqrt(mean)

output_notebook()

tools=''
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
july2024=[5445, 3108, 3379, 3095, 3427, 3452, 3684, 3668, 5612, 3771, 3151, 5264, 2384, 3236, 3513, 3538, 3639, 5398, 2723, 4499, 3199, 3786, 3686, 3250, 5961, 3256, 3983, 3784, 6874, 3082, 3508, 4661, 7695, 7499, 3296, 3469, 6892, 3009, 3191, 3060, 4161, 3587, 3568, 3322, 3086, 6612, 5361, 3446, 2712, 2733, 3510, 7498, 2789, 3061, 3567, 4451, 3770, 7223, 3349, 3186, 3330, 5530, 3104, 3137, 3026, 3733, 3067, 6410, 3268, 3478, 3873, 5471, 7651, 4595, 3356, 3024, 4199, 3871, 3659, 7863, 7271, 3778, 3020, 6861, 4507, 7862, 2763, 3703, 7747, 3624, 3133, 6723, 3327, 2734, 3816, 6931, 3390, 6848, 3219, 3037, 3408, 3319, 7591, 6818, 2747, 3118, 3555, 4085, 5836, 4515, 3008, 3126, 3409, 3589, 5952, 3099, 4635, 3392, 4834, 6964, 5203, 4775, 3293, 5703, 3336, 3581, 4493, 3455, 3003, 4843, 3572, 1133, 5928, 4547, 3558, 3653, 7251, 3285, 3476, 3556, 4519, 3092, 7550, 3075, 3630,
015, 5466, 2487, 4207, 5805, 2752, 3218, 3429, 7724, 8143, 3129, 6768, 3016, 3160, 4074, 4181, 3377, 2331, 7507, 2822, 3532, 7367, 7741, 4177, 2250, 3226, 6826, 6811, 3109, 4989, 5495, 8319, 4990, 3401, 4977, 3384, 3346, 3884, 3287, 7610, 7599, 3141, 7502, 5496, 5411, 5423, 3858, 4065, 4568, 4625, 5328, 5492, 5053, 3610, 1020, 5007, 5365, 7737, 2886, 3932, 7365, 3719, 3721, 6828, 6982, 5099, 3698, 5019]
unmoving_theta=['M01916', 'M03321', 'M03545', 'M03622', 'M04013', 'M04635', 'M04711', 'M04712', 'M04722', 'M04763', 'M05066', 'M05084', 'M05797', 'M07638', 'M07863', 'M08097', 'M08474']
unmoving_phi=["M01758",	"M01865","M03415","M04235","M04386","M04763",	"M05797"]
offset_theta=["M01722",	"M01749",	"M02251",	"M02437",	"M02500",	"M02561",	"M02708",	"M02725",	"M02848",	"M02899",	"M03075",	"M03242",	"M03415",	"M03572",	"M03848",	"M04081",	"M04083",	"M04376",	"M04386",	"M04596",	"M04601",	"M05982",	"M06167",	"M06666",	"M06667",	"M06683"]
offset_phi=["M00469",	"M01102",	"M01106",	"M01289",	"M01376",	"M01468",	"M01482",	"M01484",	"M01491",	"M01496",	"M01497",	"M01502",	"M01613",	"M01677",	"M01722",	"M01749",	"M01750",	"M01759",	"M01768",	"M01778",	"M01831",	"M01834",	"M01861",	"M01875",	"M01887",	"M01896",	"M01929",	"M01946",	"M01953",	"M01976",	"M02164",	"M02248",	"M02265",	"M02328",	"M02361",	"M02453",	"M02482",	"M02493",	"M02525",	"M03077",	"M03175",	"M03254",	"M03379",	"M03444",	"M03455",	"M03464",	"M03583",	"M03588",	"M03613",	"M03614",	"M03618",	"M03642",	"M03653",	"M03655",	"M03661",	"M03680",	"M03721",	"M03725",	"M03733",	"M03772",	"M03901",	"M03906",	"M03915",	"M03925",	"M03950",	"M03961",	"M03983",	"M03995",	"M03998",	"M04006",	"M04009",	"M04055",	"M04058",	"M04060",	"M04078",	"M04081",	"M04178",	"M04199",	"M04253",	"M04270",	"M04354",	"M04356",	"M04361",	"M04385",	"M04416",	"M04569",	"M04619",	"M04718",	"M04981",	"M05029",	"M05040",	"M05042",	"M05048",	"M05089",	"M05096",	"M05107",	"M05178",	"M05362",	"M05461",	"M05506",	"M05882",	"M06080",	"M06663",	"M06685",	"M06861",	"M06898",	"M06933",	"M07085",	"M07180",	"M07241",	"M07274",	"M07338",	"M07383",	"M07504",	"M07550",	"M07656",	"M08097",	"M08190",	"M08230",	"M08299",	"M08337"]
lin_theta=["M03330",	"M03379",	"M03558",	"M03581",	"M03712",	"M03873",	"M05398",	"M05703",	"M06612",	"M06891",	"M06986",	"M07525"]
lin_phi=["M00436",	"M01080",	"M01102",	"M01106",	"M01276",	"M01289",	"M01376",	"M01482",	"M01484",	"M01491",	"M01632",	"M01677",	"M01709",	"M01759",	"M01764",	"M01778",	"M01861",	"M01875",	"M01896",	"M01916",	"M01929",	"M01946",	"M01953",	"M01976",	"M02164",	"M02190",	"M02254",	"M02323",	"M02361",	"M02369",	"M02430",	"M02453",	"M02481",	"M02488",	"M02490",	"M02493",	"M02500",	"M02505",	"M02525",	"M02947",	"M03090",	"M03172",	"M03187",	"M03443",	"M03444",	"M03455",	"M03456",	"M03461",	"M03464",	"M03491",	"M03520",	"M03545",	"M03584",	"M03588",	"M03601",	"M03607",	"M03609",	"M03614",	"M03618",	"M03622",	"M03633",	"M03645",	"M03649",	"M03650",	"M03653",	"M03654",	"M03655",	"M03661",	"M03672",	"M03675",	"M03676",	"M03680",	"M03684",	"M03696",	"M03709",	"M03721",	"M03725",	"M03729",	"M03733",	"M03734",	"M03735",	"M03772",	"M03777",	"M03792",	"M03794",	"M03809",	"M03811",	"M03816",	"M03820",	"M03848",	"M03889",	"M03906",	"M03913",	"M03915",	"M03917",	"M03918",	"M03925",	"M03935",	"M03940",	"M03941",	"M03945",	"M03947",	"M03954",	"M03961",	"M03962",	"M03963",	"M03975",	"M03978",	"M03979",	"M03981",	"M03983",	"M03986",	"M03987",	"M03998",	"M04006",	"M04012",	"M04013",	"M04024",	"M04031",	"M04044",	"M04052",	"M04060",	"M04062",	"M04078",	"M04084",	"M04086",	"M04178",	"M04182",	"M04191",	"M04197",	"M04199",	"M04201",	"M04205",	"M04213",	"M04253",	"M04265",	"M04271",	"M04307",	"M04309",	"M04318",	"M04319",	"M04330",	"M04337",	"M04343",	"M04354",	"M04356",	"M04361",	"M04363",	"M04373",	"M04376",	"M04379",	"M04381",	"M04383",	"M04389",	"M04396",	"M04401",	"M04416",	"M04422",	"M04619",	"M04718",	"M04981",	"M04982",	"M04984",	"M04995",	"M04999",	"M05000",	"M05029",	"M05048",	"M05052",	"M05062",	"M05074",	"M05086",	"M05107",	"M05112",	"M05114",	"M05132",	"M05178",	"M05218",	"M05262",	"M05268",	"M05362",	"M05363",	"M05376",	"M05453",	"M05461",	"M05499",	"M05506",	"M05508",	"M05862",	"M05888",	"M05977",	"M06167",	"M06663",	"M06683",	"M06863",	"M06898",	"M06933",	"M07081",	"M07085",	"M07119",	"M07125",	"M07180",	"M07241",	"M07274",	"M07338",	"M07383",	"M07480",	"M07595",	"M07715",	"M07733",	"M08217",	"M08230",	"M08299"]

july=['M0'+str(i) for i in july2024]
s1=set(unmoving_phi) & set(july)
s2=set(unmoving_theta) & set(july)
s3=set(offset_theta) & set(july)
s4=set(offset_phi) & set(july)
s5=set(lin_phi) & set(july)
s6=set(lin_theta) & set(july)
s=set(list(s1)+list(s2)+list(s3)+list(s4)+list(s5))
print('')
print(len(s))
# Out:
# 230

# %%
import pandas as pd
filename ='/Users/michael/Downloads/Motor_Issue_Stats_dec_31_2023.csv'
filename ='/Users/michael/Downloads/Motor_Issue_Stats_June_1_2024.csv'
filename ='/Users/michael/Downloads/Motor_Issue_Stats_July_1_2024.csv'
filename ='/Users/michael/Downloads/Motor_Issue_Stats_Oct_1_2024.csv'
filename ='/Users/michael/Downloads/Motor_Issue_Stats_Sep_26_2025.csv'
filename ='/Users/michael/Downloads/Motor_Issue_Stats_Feb_3_2026.csv'
filename ='../data/raw/Motor_Issue_Stats_July_4_2026.csv'

# %%
def crack_to_phi_estimate(n_lin_2018=307,ok_2018=4300,crack_rate=0.145, phi_rate=0.115):
    years=[2018,2019,2020,2021,2022,2023,2024]
    n_days=[0,356,712,1068,1424,1780,2136]
    n_cracked=[0,0,0,0,0,0,0]
    n_ok=[ok_2018,0,0,0,0,0,0]
    n_lin_phi=[n_lin_2018,0,0,0,0,0,0]

    #crack_rate=0.145
    #lin_rate=0.115

    n_cracked[0]=10000-n_ok[0]
    for i in [1,2,3,4,5,6]:
        n_cracked[i]=n_cracked[i-1]+n_ok[i-1]*crack_rate
        n_ok[i]=10000-n_cracked[i]
        n_lin_phi[i]=n_lin_phi[i-1]+(n_cracked[i]-n_cracked[i-1])*phi_rate
    for i in [0,1,2,3,4,5,6]:
        print(years[i], n_lin_phi[i],n_days[i],n_ok[i],n_cracked[i])
    return n_lin_phi

def read_clairs_csv_file(filename):
    #df = pd.read_csv(filename)
    df = pd.read_csv(filename, usecols = ['POS_ID', 'SCALE_P', 'SCALE_T', 'DATE'],parse_dates=True) 
    print(df.shape)
    # drop all rows where we did not move
    #df = df[df['dx'].isna()]
    #df = df.dropna(axis=0, subset=['move_val1'])
    #print(df.shape)
    # seect only columns we want to keep
    df_pos = df['POS_ID']
    return df


df = read_clairs_csv_file(filename)
scale_p = list(df['SCALE_P'])
scale_t = list(df['SCALE_T'])
date = pd.to_datetime(df['DATE'])

#print(date)

is_lin_p = [True if s < 1. else False for s in scale_p]
is_lin_t = [True if s < 1. else False for s in scale_t]
dates = sorted(set(date))
ddates = {d:{'n_lin_p':0, 'n_lin_t':0, 'cum_lin_p':0, 'cum_lin_t':0} for d in dates}
#print(dates)
print('done')
# Out:
# (617, 4)
# done

# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Load the CSV file
df = pd.read_csv(filename, usecols = ['POS_ID', 'SCALE_P', 'SCALE_T', 'DATE'], parse_dates=['DATE'])
print(list(df['POS_ID']))
# Generate a mask for less than 1 values
mask_p = df['SCALE_P'] < 1
mask_t = df['SCALE_T'] < 1

# Apply the mask and then replace non-masked values with zero
#df['SCALE_P'] = df['SCALE_P'].where(mask_p, 0)
#df['SCALE_T'] = df['SCALE_T'].where(mask_t, 0)

# Group by date and calculate the cumulative sum
#df_grouped = df.groupby('DATE')

#cumulative_stats = {}
#for date, group in df_grouped:
#    cumulative_stats[date] = {
#        'SCALE_P': group['SCALE_P'].sum(),
#        'SCALE_T': group['SCALE_T'].sum()
#    }

# Apply the mask to the columns
df['SCALE_P'] = mask_p
df['SCALE_T'] = mask_t

# Convert the boolean values to int for counting
df[['SCALE_P', 'SCALE_T']] = df[['SCALE_P', 'SCALE_T']].astype(int)

# Group by date and calculate the sum for each group
df_grouped = df.groupby('DATE').sum()

# Calculate the cumulative sum over the date
df_grouped = df_grouped.cumsum()

#df_grouped.loc[len(df_grouped.index)] = [pd.to_datetime('2024-07-01'), 2582685,      350,      252] 
#print(df_grouped.tail(1))
df_grouped.loc[df_grouped.index[-1], 'SCALE_P'] = 350
#print(df_grouped.tail(1))
#df_grouped[pd.to_datetime('2024-07-01')] = [ 2582685,      350,      252] 
df_grouped['SCALE_SUM'] = df_grouped['SCALE_P'] + df_grouped['SCALE_T']   # Add SCALE_P and SCALE_T


# Create a dictionary from the resultant DataFrame
cumulative_stats_count = df_grouped.to_dict('index')

# print cumulative results
#print(cumulative_stats_count)

# make plot
                             
# Create a new plot with a datetime axis type
                             
p = figure(width=800, height=400, x_axis_type="datetime")

# Add renderers for SCALE_T, SCALE_P, and SCALE_T+SCALE_P
p.line(df_grouped.index, df_grouped['SCALE_T'], color='blue', alpha=0.5, legend_label="SCALE_T")
p.line(df_grouped.index, df_grouped['SCALE_P'], color='red', alpha=0.5, legend_label="SCALE_P")
p.line(df_grouped.index, df_grouped['SCALE_SUM'], color='green', alpha=0.5, legend_label="SCALE_T+SCALE_P")
     
# Customize the plot
p.legend.location = "top_left"
p.legend.click_policy="hide"

# Show the plot
show(p)
# Out:
# [5445, 3108, 3379, 3095, 3427, 3452, 3684, 3668, 5612, 3771, 3151, 5264, 2384, 3236, 3513, 3538, 3639, 5398, 2723, 4499, 3199, 3786, 3686, 3250, 5961, 3256, 3983, 3784, 6874, 3082, 3508, 4661, 7695, 7499, 3296, 3469, 6892, 3009, 3191, 3060, 4161, 3587, 3568, 3322, 3086, 6612, 5361, 3446, 2712, 2733, 3510, 7498, 2789, 3061, 3567, 4451, 3770, 7223, 3349, 3186, 3330, 5530, 3104, 3137, 3026, 3733, 3067, 6410, 3268, 3478, 3873, 5471, 7651, 4595, 3356, 3024, 4199, 3871, 3659, 7863, 7271, 3778, 3020, 6861, 4507, 7862, 2763, 3703, 7747, 3624, 3133, 6723, 3327, 2734, 3816, 6931, 3390, 6848, 3219, 3037, 3408, 3319, 7591, 6818, 2747, 3118, 3555, 4085, 5836, 4515, 3008, 3126, 3409, 3589, 5952, 3099, 4635, 3392, 4834, 6964, 5203, 4775, 3293, 5703, 3336, 3581, 4493, 3455, 3003, 4843, 3572, 1133, 5928, 4547, 3558, 3653, 7251, 3285, 3476, 3556, 4519, 3092, 7550, 3075, 3630, 2719, 3676, 3146, 3655, 3519, 1497, 3253, 8015, 3254, 3315, 6757, 3122, 7073, 3570, 3712, 2720, 5066, 3230, 3874, 7364, 3583, 3
# ...

# %%
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from pandas.tseries.offsets import DateOffset
from datetime import datetime
from scipy import stats
from bokeh.models import BoxAnnotation


verbose=False

# Load the CSV file
df = pd.read_csv(filename, usecols = ['POS_ID', 'SCALE_P', 'SCALE_T', 'DATE'], parse_dates=['DATE'])


# Generate a mask for values less than 1
mask_p = df['SCALE_P'] < 1
mask_t = df['SCALE_T'] < 1

# Apply the mask to the columns
df['SCALE_P'] = mask_p
df['SCALE_T'] = mask_t

# Convert the boolean values to integer type. 
df[['SCALE_P', 'SCALE_T']] = df[['SCALE_P', 'SCALE_T']].astype(int)

# Group by date and calculate the sum
df_grouped = df.groupby('DATE').sum()

# Calculate the cumulative sum over the date
df_grouped = df_grouped.cumsum()
#df_grouped.loc[df_grouped.index[-1], 'SCALE_P'] = 350
df_grouped['SCALE_SUM'] = df_grouped['SCALE_P'] + df_grouped['SCALE_T']   # Add SCALE_P and SCALE_T

if verbose:

    print(list(df_grouped['SCALE_P']))
    print(' ')
    print(list(df_grouped['SCALE_T']))

    print('***')

# Create a line with an increase of 1 per week
start_date = pd.to_datetime('2021-02-07')
end_date = pd.to_datetime('2029-01-01') #df_grouped.index.max()
slope_line = pd.date_range(start=start_date, end=end_date, freq='W')
slope_line_values = [i + df_grouped.loc[start_date, 'SCALE_SUM'] if start_date in df_grouped.index else i for i in range(len(slope_line))]

# Prepare output to Jupyter notebook
output_notebook()

# Create a new plot with a datetime axis type
model = True

if model:
    p = figure(width=800, height=400, x_axis_type="datetime",y_range=[300,700], 
               x_range = (pd.Timestamp('2018-01-01'), pd.Timestamp('2034-01-01')))
else:
    p = figure(width=800, height=400, x_axis_type="datetime",y_range=[450,650]) #, x_range = (x_min, x_max))

slope_line_values = np.array(slope_line_values)+df_grouped['SCALE_SUM'][0]
slope_line_values2 = slope_line_values-10


# Add renderers for SCALE_T, SCALE_P, SCALE_SUM, and the line with slope
lw=2.5
#p.line(df_grouped.index, df_grouped['SCALE_T'], color='blue', line_width=lw,alpha=0.5, legend_label="Lin T")
#p.line(df_grouped.index, df_grouped['SCALE_P'], color='red', line_width=lw,alpha=0.5, legend_label="Lin P")
p.line(df_grouped.index, df_grouped['SCALE_SUM'], color='green', line_width=lw,alpha=0.75, 
       legend_label="Lin P+T")

# 
old_model=False
if old_model:

    p.line(slope_line, slope_line_values, color='purple', alpha=0.75,line_dash='dashed',
           line_width=lw, legend_label="1/week")

p.circle(df_grouped.index, df_grouped['SCALE_SUM'], color='blue',alpha=0.75, legend_label="Lin P+T")
if True:
    print(list(df_grouped['SCALE_SUM']))
    print(list(df_grouped.index))      

second_slope = False
if second_slope:
    p.line(slope_line[100:], slope_line_values2[100:], color='darkorange', alpha=0.75, line_dash='dashed',line_width=lw,
       legend_label="1/week mod")

# Customize the plot
p.legend.location = "top_left"
p.legend.click_policy="hide"


#p.xaxis.axis_label='Dte'
p.yaxis.axis_label='Cumulative Motor Failures'
p.xaxis.axis_label_text_font_size = '12pt'
p.yaxis.axis_label_text_font_size = '12pt'
p.xaxis.major_label_text_font_size = '12pt'
p.yaxis.major_label_text_font_size = '12pt'
p.title.text_font_size = '12pt'


seasons = [[pd.to_datetime('2021-04-01'),pd.to_datetime('2021-04-01')],
           [pd.to_datetime('2021-10-01'),pd.to_datetime('2021-10-01')],
           [pd.to_datetime('2022-04-01'),pd.to_datetime('2022-04-01')],
           [pd.to_datetime('2022-10-01'),pd.to_datetime('2022-10-01')],
           [pd.to_datetime('2023-04-01'),pd.to_datetime('2023-04-01')],
           [pd.to_datetime('2023-10-01'),pd.to_datetime('2023-10-01')]]
          
markers=[460.,590.]

plot_seasons = False
if plot_seasons:
    for s in seasons:
        if verbose:
            print(s)
        p.line(s, markers, color='deepskyblue', alpha=0.75, line_width=1.5)

# fit seasons
    
DATA = list(df_grouped['SCALE_SUM'])
DATES = list(df_grouped.index)

# create a DataFrame
df = pd.DataFrame({'Date':DATES, 'Data':DATA})

#regions=[[pd.Timestamp('2021-04-01'),pd.Timestamp( '2021-10-01')],
#        [pd.Timestamp('2021-10-01'),pd.Timestamp( '2022-04-01')],
#        [pd.Timestamp('2022-04-01'),pd.Timestamp( '2022-10-01')],
#        [pd.Timestamp('2022-10-01'),pd.Timestamp( '2023-04-01')],        
#        [pd.Timestamp('2023-04-01'),pd.Timestamp( '2023-10-01')]]

#plot_regions = False
#if plot_regions:
#    
#    for REGION in regions:
#        #REGION = [pd.Timestamp('2021-04-01'),pd.Timestamp( '2021-10-01')]
#        # filter data
#        df = pd.DataFrame({'Date':DATES, 'Data':DATA})
#        df = df[(df['Date'] >= REGION[0]) & (df['Date'] <= REGION[1])]
#        # Convert dates into numerical format for polyfit
#        df['NUM_DATES'] = df['Date'].apply(lambda x: x.value)  
#        # perform least square fit
#        coeffs = np.polyfit(df['NUM_DATES'], df['Data'], 1)
#        print('coeffs',coeffs,coeffs[0]*(7*24*60*60*1e9))
#        poly = np.poly1d(coeffs)
#        # Generate y-values for the fitted line
#        df['FITTED'] = poly(df['NUM_DATES'])#
#
#        p.line(df['Date'], df['FITTED'], color="crimson", alpha=0.75,line_width=3)

if model:
    from scipy.stats import weibull_min
    years_since_start = [0.0, 4.0, 5.0, 6.0, 7.0,18]  #18
    time = np.linspace(0, max(years_since_start), 100)
    shape_param = 1.4 # this is a common assumption, but it should be fitted from data
    # ...and scale parameter (eta)
    scale_param = 3.5 # this is a simple guess, and should also be fitted from data
    
    shape_param = 1.475 # 1.4 
    scale_param = 3.6
    
    weibull_cdf = weibull_min.cdf(time, shape_param, scale=scale_param)
    
    
    print (weibull_cdf)
    
    dates=[pd.Timestamp('2017-01-01'), pd.Timestamp( '2021-01-01'),
            pd.Timestamp('2022-01-01'), pd.Timestamp( '2023-01-01'),
            pd.Timestamp('2024-01-01')]
    if verbose:
        print(dates)
    start_date = '2017-01-01'

    # Number of days since the starting date
    days_since_start = time * 356
    start_timestamp = pd.to_datetime(start_date)
    timestamps = [start_timestamp + pd.Timedelta(days=d) for d in days_since_start]
    #estimates = crack_to_phi_estimate(270,4500,crack_rate=0.135, phi_rate=0.125)
    weibull_cdf =weibull_cdf*635
    p.line(timestamps, weibull_cdf, line_width=2,color='darkorange',alpha=0.75, legend_label="model")
    
    #p.circle(pd.Timestamp('2020-02-14'), 230, color='blue',alpha=0.75)

    # 1. Model - 200, vertical step at June 2024
    #step1_date = pd.Timestamp("2024-06-01")
    #idx1 = np.searchsorted(timestamps, step1_date)

    # Draw vertical from model to offset at step1_date
    #p.line([timestamps[idx1], timestamps[idx1]], 
    #       [weibull_cdf[idx1], weibull_cdf[idx1] - 200], 
    #       color='#4682B4', line_width=2)

    # Draw the -200 offset from step1_date forward
    #p.line(timestamps[idx1:], weibull_cdf[idx1:] - 200, 
    #       color='#4682B4', line_width=2)

    # 2. Model - 350, vertical step at May 2026
    #step2_date = pd.Timestamp("2026-05-01")
    #idx2 = np.searchsorted(timestamps, step2_date)

    # Draw vertical from model to offset at step2_date
    #p.line([timestamps[idx2], timestamps[idx2]], 
    #       [weibull_cdf[idx2], weibull_cdf[idx2] - 350], 
    #       color='#3CB371', line_width=2,line_dash="dashed")

    # Draw the -350 offset from step2_date forward
    #p.line(timestamps[idx2:], weibull_cdf[idx2:] - 350, 
    #       color='#3CB371', line_width=2,line_dash="dashed")


p.xaxis.axis_label='Date'

p.xaxis.axis_label_text_font_size = '16pt'
p.yaxis.axis_label_text_font_size = '16pt'
p.xaxis.major_label_text_font_size = '14pt'
p.yaxis.major_label_text_font_size = '14pt'
p.title.text_font_size = '14pt'
# Show the plot

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p3468">Loading BokehJS ...</span>
#     </div>
# [467, 468, 469, 470, 471, 472, 474, 476, 477, 478, 479, 480, 481, 482, 483, 485, 486, 498, 500, 502, 503, 504, 505, 506, 507, 508, 509, 511, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 526, 529, 530, 531, 532, 533, 534, 535, 543, 545, 546, 550, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 570, 571, 573, 574, 575, 576, 577, 578, 579, 580, 586, 588, 589, 590, 591, 592, 593, 594, 595, 596, 598, 599, 600, 601, 604, 605, 609, 613, 614, 616, 617, 618, 619, 621, 622, 623, 624, 625, 625, 626, 627]
# ...

# %%
p = figure(..., x_axis_type='datetime', ...)

# %%
# Out:
# (403299, 22)
# (50625, 22)

# %%
def outer_func(x):
    y = 4
    def inner_func(z):
        print(f"x = {x}, y = {y}, z = {z}")
        return x + y + z
    return inner_func

for i in range(3):
    closure = outer_func(i)
    print(f"closure({i+5}) = {closure(i+5)}")
# Out:
# x = 0, y = 4, z = 5
# closure(5) = 9
# x = 1, y = 4, z = 6
# closure(6) = 11
# x = 2, y = 4, z = 7
# closure(7) = 13

# %%
def crack_to_phi_estimate(n_lin_2018=307,ok_2018=4300,crack_rate=0.105, phi_rate=0.115):
    years=[2018,2019,2020,2021,2022,2023,2024]
    n_days=[0,356,712,1068,1424,1780,2136]
    n_cracked=[0,0,0,0,0,0,0]
    n_ok=[ok_2018,0,0,0,0,0,0]
    n_lin_phi=[n_lin_2018,0,0,0,0,0,0]

    #crack_rate=0.145
    #lin_rate=0.115

    n_cracked[0]=10000-n_ok[0]
    for i in [1,2,3,4,5,6]:
        n_cracked[i]=n_cracked[i-1]+n_ok[i-1]*crack_rate
        n_ok[i]=10000-n_cracked[i]
        n_lin_phi[i]=n_lin_phi[i-1]+(n_cracked[i]-n_cracked[i-1])*phi_rate
    for i in [0,1,2,3,4,5,6]:
        print(years[i], n_lin_phi[i],n_days[i],n_ok[i],n_cracked[i])
    return n_lin_phi

# %%
# Out:
# -229.82521876562

# %%
def crack_to_phi_estimate_old(n_lin_2018=307,ok_2018=4300,crack_rate=0.145, phi_rate=0.115):
    years=[2018,2019,2020,2021,2022,2023,2024]
    n_days=[0,356,712,1068,1424,1780,2136]
    n_cracked=[0,0,0,0,0,0,0]
    n_ok=[ok_2018,0,0,0,0,0,0]
    n_lin_phi=[n_lin_2018,0,0,0,0,0,0]

    #crack_rate=0.145
    #lin_rate=0.115

    n_cracked[0]=10000-n_ok[0]
    for i in [1,2,3,4,5,6]:
        n_cracked[i]=n_cracked[i-1]+n_ok[i-1]*crack_rate
        n_ok[i]=10000-n_cracked[i]
        n_lin_phi[i]=n_lin_phi[i-1]+(n_cracked[i]-n_cracked[i-1])*phi_rate
    for i in [0,1,2,3,4,5,6]:
        print(years[i], n_lin_phi[i],n_days[i],n_ok[i],n_cracked[i])
    return n_lin_phi

# %%
# 2026 NEW Weibull


import pandas as pd
import numpy as np
from datetime import datetime

# Example start date for production
start_date = pd.Timestamp('2019-08-01')

# Your timestamps list:
#timestamps = [Timestamp('2021-02-02 00:00:00'), Timestamp('2021-02-09 00:00:00'), Timestamp('2021-02-24 00:00:00'), Timestamp('2021-04-03 00:00:00'), Timestamp('2021-04-04 00:00:00'), Timestamp('2021-04-15 00:00:00'), Timestamp('2021-05-11 00:00:00'), Timestamp('2021-05-15 00:00:00'), Timestamp('2021-05-16 00:00:00'), Timestamp('2021-05-19 00:00:00'), Timestamp('2021-06-01 00:00:00'), Timestamp('2021-06-09 00:00:00'), Timestamp('2021-06-13 00:00:00'), Timestamp('2021-06-14 00:00:00'), Timestamp('2021-06-20 00:00:00'), Timestamp('2021-06-27 00:00:00'), Timestamp('2021-07-05 00:00:00'), Timestamp('2021-07-08 00:00:00'), Timestamp('2021-07-09 00:00:00'), Timestamp('2021-09-16 00:00:00'), Timestamp('2021-09-20 00:00:00'), Timestamp('2021-09-22 00:00:00'), Timestamp('2021-09-27 00:00:00'), Timestamp('2021-10-11 00:00:00'), Timestamp('2021-10-17 00:00:00'), Timestamp('2021-11-02 00:00:00'), Timestamp('2021-11-14 00:00:00'), Timestamp('2021-11-17 00:00:00'), Timestamp('2021-11-18 00:00:00'), Timestamp('2021-11-26 00:00:00'), Timestamp('2021-12-11 00:00:00'), Timestamp('2022-01-02 00:00:00'), Timestamp('2022-01-21 00:00:00'), Timestamp('2022-01-25 00:00:00'), Timestamp('2022-02-10 00:00:00'), Timestamp('2022-02-11 00:00:00'), Timestamp('2022-02-26 00:00:00'), Timestamp('2022-03-01 00:00:00'), Timestamp('2022-03-10 00:00:00'), Timestamp('2022-03-16 00:00:00'), Timestamp('2022-03-22 00:00:00'), Timestamp('2022-03-28 00:00:00'), Timestamp('2022-04-27 00:00:00'), Timestamp('2022-05-05 00:00:00'), Timestamp('2022-05-09 00:00:00'), Timestamp('2022-05-10 00:00:00'), Timestamp('2022-05-11 00:00:00'), Timestamp('2022-05-17 00:00:00'), Timestamp('2022-06-05 00:00:00'), Timestamp('2022-06-07 00:00:00'), Timestamp('2022-06-10 00:00:00'), Timestamp('2022-09-02 00:00:00'), Timestamp('2022-09-11 00:00:00'), Timestamp('2022-09-16 00:00:00'), Timestamp('2022-09-17 00:00:00'), Timestamp('2022-09-18 00:00:00'), Timestamp('2022-09-19 00:00:00'), Timestamp('2022-09-23 00:00:00'), Timestamp('2022-10-18 00:00:00'), Timestamp('2022-10-21 00:00:00'), Timestamp('2022-10-25 00:00:00'), Timestamp
amp('2023-10-16 00:00:00'), pd.Timestamp('2023-12-04 00:00:00'), pd.Timestamp('2023-12-31 00:00:00'), pd.Timestamp('2024-01-17 00:00:00'), pd.Timestamp('2024-01-19 00:00:00'), pd.Timestamp('2024-01-26 00:00:00'), pd.Timestamp('2024-02-12 00:00:00'), pd.Timestamp('2024-02-20 00:00:00'), pd.Timestamp('2024-03-14 00:00:00'), pd.Timestamp('2024-03-22 00:00:00'), pd.Timestamp('2024-07-11 00:00:00'), pd.Timestamp('2024-07-31 00:00:00'), pd.Timestamp('2024-08-22 00:00:00'), pd.Timestamp('2024-09-22 00:00:00'), pd.Timestamp('2024-10-12 00:00:00'), pd.Timestamp('2024-11-04 00:00:00'), pd.Timestamp('2024-11-14 00:00:00'), pd.Timestamp('2024-11-15 00:00:00'), pd.Timestamp('2024-12-02 00:00:00'), pd.Timestamp('2025-05-28 00:00:00'), pd.Timestamp('2025-07-11 00:00:00'), pd.Timestamp('2025-08-05 00:00:00'), pd.Timestamp('2025-12-02 00:00:00'), pd.Timestamp('2025-12-06 00:00:00'), pd.Timestamp('2026-01-28 00:00:00')]



# Calculate time since start in days (or months if preferred)
durations = [(ts - start_date).days for ts in timestamps]
# OR, for months: durations = [(ts.year - start_date.year)*12 + (ts.month - start_date.month) for ts in timestamps]

# Your cumulative failures
cum_failures = np.array([467, 468, 469, 470, 471, 472, 474, 476, 477, 479, 480, 481, 482, 483, 484, 486, 487, 488, 489, 501, 503, 505, 506, 507, 508, 509, 510, 511, 512, 514, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 530, 533, 534, 535, 536, 537, 538, 539, 547, 549, 550, 554, 556, 557, 558, 558, 558, 558, 558, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 570, 571, 573, 574, 575, 576, 577, 578, 579, 585, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 599, 600, 601, 602, 605, 606, 607, 611, 615, 616, 618, 619, 620, 621, 623, 624, 625, 626, 627])

total_produced = cum_failures[-1]  # Assuming last value is total failures at last date
ecdf = cum_failures   # Fraction failed 


from scipy.optimize import curve_fit

def weibull_cdf(N, t, lam, k):
    return N(1 - exp.exp(-( t / lam) ** k))

params, _ = curve_fit(weibull_cdf, N, durations, ecdf, p0=[2000, 1])
lam_hat, k_hat = params
print(f"Estimated scale (lambda): {lam_hat:.2f}")
print(f"Estimated shape (k): {k_hat:.2f}")

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()  # Or use output_file if not in notebook

# Generate fit line
t_fit = np.linspace(min(durations), max(durations), 200)
fit_ecdf = weibull_cdf(t_fit, lam_hat, k_hat)

p = figure(title="Weibull Fit to Cumulative Failure Data",
           x_axis_label="Days Since Start of Production",
           y_axis_label="Fraction Failed",
           tools="pan,box_zoom,reset,save",
          x_range=(0,4000),y_range=(0.,0.2))

# Data points
p.circle(durations, ecdf, size=8, color="navy", alpha=0.7, legend_label='Empirical ECDF')
# Weibull fit
p.line(t_fit, fit_ecdf, line_width=3, color="red", alpha=0.8, legend_label='Weibull Fit')

p.legend.location = "bottom_right"
show(p)
# Out:
# Estimated scale (lambda): 0.54
# Estimated shape (k): 0.62
# <ipython-input-67-0acae308a2ff>:33: RuntimeWarning: invalid value encountered in power
#   return 1 - np.exp(-(t / lam) ** k)
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p87640">Loading BokehJS ...</span>
#     </div>
#   <div id="c116a2ac-9e7f-4016-b180-6987a339cae5" data-root-id="p87641" style="display: contents;"></div>

# %%
import numpy as np
from scipy.optimize import curve_fit
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()


# Example start date for production
start_date = pd.Timestamp('2019-01-01')

duan_time=pd.Timestamp('2020-02-14 00:00:00')
duan_num=286+25 #424
duan_time=(duan_time-start_date).days
# Your timestamps list:
#timestamps = [Timestamp('2021-02-02 00:00:00'), Timestamp('2021-02-09 00:00:00'), Timestamp('2021-02-24 00:00:00'), Timestamp('2021-04-03 00:00:00'), Timestamp('2021-04-04 00:00:00'), Timestamp('2021-04-15 00:00:00'), Timestamp('2021-05-11 00:00:00'), Timestamp('2021-05-15 00:00:00'), Timestamp('2021-05-16 00:00:00'), Timestamp('2021-05-19 00:00:00'), Timestamp('2021-06-01 00:00:00'), Timestamp('2021-06-09 00:00:00'), Timestamp('2021-06-13 00:00:00'), Timestamp('2021-06-14 00:00:00'), Timestamp('2021-06-20 00:00:00'), Timestamp('2021-06-27 00:00:00'), Timestamp('2021-07-05 00:00:00'), Timestamp('2021-07-08 00:00:00'), Timestamp('2021-07-09 00:00:00'), Timestamp('2021-09-16 00:00:00'), Timestamp('2021-09-20 00:00:00'), Timestamp('2021-09-22 00:00:00'), Timestamp('2021-09-27 00:00:00'), Timestamp('2021-10-11 00:00:00'), Timestamp('2021-10-17 00:00:00'), Timestamp('2021-11-02 00:00:00'), Timestamp('2021-11-14 00:00:00'), Timestamp('2021-11-17 00:00:00'), Timestamp('2021-11-18 00:00:00'), Timestamp('2021-11-26 00:00:00'), Timestamp('2021-12-11 00:00:00'), Timestamp('2022-01-02 00:00:00'), Timestamp('2022-01-21 00:00:00'), Timestamp('2022-01-25 00:00:00'), Timestamp('2022-02-10 00:00:00'), Timestamp('2022-02-11 00:00:00'), Timestamp('2022-02-26 00:00:00'), Timestamp('2022-03-01 00:00:00'), Timestamp('2022-03-10 00:00:00'), Timestamp('2022-03-16 00:00:00'), Timestamp('2022-03-22 00:00:00'), Timestamp('2022-03-28 00:00:00'), Timestamp('2022-04-27 00:00:00'), Timestamp('2022-05-05 00:00:00'), Timestamp('2022-05-09 00:00:00'), Timestamp('2022-05-10 00:00:00'), Timestamp('2022-05-11 00:00:00'), Timestamp('2022-05-17 00:00:00'), Timestamp('2022-06-05 00:00:00'), Timestamp('2022-06-07 00:00:00'), Timestamp('2022-06-10 00:00:00'), Timestamp('2022-09-02 00:00:00'), Timestamp('2022-09-11 00:00:00'), Timestamp('2022-09-16 00:00:00'), Timestamp('2022-09-17 00:00:00'), Timestamp('2022-09-18 00:00:00'), Timestamp('2022-09-19 00:00:00'), Timestamp('2022-09-23 00:00:00'), Timestamp('2022-10-18 00:00:00'), Timestamp('2022-10-21 00:00:00'), Timestamp('2022-10-25 00:00:00'), Timestamp('2022-10-26 00:00:00'), Timestamp('2022-10-27 00:00:00'), Timestamp('2022-11-17 00:00:00'), Timestamp('2022-11-20 00:00:00'), Timest
00'), pd.Timestamp('2021-10-17 00:00:00'), pd.Timestamp('2021-11-02 00:00:00'), pd.Timestamp('2021-11-14 00:00:00'), pd.Timestamp('2021-11-17 00:00:00'), pd.Timestamp('2021-11-18 00:00:00'), pd.Timestamp('2021-11-26 00:00:00'), pd.Timestamp('2021-12-11 00:00:00'), pd.Timestamp('2022-01-02 00:00:00'), pd.Timestamp('2022-01-21 00:00:00'), pd.Timestamp('2022-01-25 00:00:00'), pd.Timestamp('2022-02-10 00:00:00'), pd.Timestamp('2022-02-11 00:00:00'), pd.Timestamp('2022-02-26 00:00:00'), pd.Timestamp('2022-03-01 00:00:00'), pd.Timestamp('2022-03-10 00:00:00'), pd.Timestamp('2022-03-16 00:00:00'), pd.Timestamp('2022-03-22 00:00:00'), pd.Timestamp('2022-03-28 00:00:00'), pd.Timestamp('2022-04-27 00:00:00'), pd.Timestamp('2022-05-05 00:00:00'), pd.Timestamp('2022-05-09 00:00:00'), pd.Timestamp('2022-05-10 00:00:00'), pd.Timestamp('2022-05-11 00:00:00'), pd.Timestamp('2022-05-17 00:00:00'), pd.Timestamp('2022-06-05 00:00:00'), pd.Timestamp('2022-06-07 00:00:00'), pd.Timestamp('2022-06-10 00:00:00'), pd.Timestamp('2022-09-02 00:00:00'), pd.Timestamp('2022-09-11 00:00:00'), pd.Timestamp('2022-09-16 00:00:00'), pd.Timestamp('2022-09-17 00:00:00'), pd.Timestamp('2022-09-18 00:00:00'), pd.Timestamp('2022-09-19 00:00:00'), pd.Timestamp('2022-09-23 00:00:00'), pd.Timestamp('2022-10-18 00:00:00'), pd.Timestamp('2022-10-21 00:00:00'), pd.Timestamp('2022-10-25 00:00:00'), pd.Timestamp('2022-10-26 00:00:00'), pd.Timestamp('2022-10-27 00:00:00'), pd.Timestamp('2022-11-17 00:00:00'), pd.Timestamp('2022-11-20 00:00:00'), pd.Timestamp('2022-11-28 00:00:00'), pd.Timestamp('2022-11-30 00:00:00'), pd.Timestamp('2023-01-10 00:00:00'), pd.Timestamp('2023-01-20 00:00:00'), pd.Timestamp('2023-03-04 00:00:00'), pd.Timestamp('2023-03-30 00:00:00'), pd.Timestamp('2023-04-06 00:00:00'), pd.Timestamp('2023-04-18 00:00:00'), pd.Timestamp('2023-04-19 00:00:00'), pd.Timestamp('2023-04-20 00:00:00'), pd.Timestamp('2023-04-30 00:00:00'), pd.Timestamp('2023-05-23 00:00:00'), pd.Timestamp('2023-05-28 00:00:00'), pd.Timestamp('2023-05-30 00:00:00'), pd.Timestamp('2023-06-07 00:00:00'), pd.Timestamp('2023-06-16 00:00:00'), pd.Timestamp('2023-06-19 00:00:00'), pd.Timestamp('2023-08-05 00:00:00'), pd.Timestamp('2023-08-13 00:00:00'), pd.Timestamp('2023-08-23 00:00:00'), pd.Timestamp('2023-09-04 00:00:00'), pd.Timestamp('2023-09-14 00:00:00'), pd.Timestamp('2023-10-09 00:00:00'), pd.Timestamp('2023-10-16 00:00:00'), pd.Timestamp('2023-12-04 00:00:00'), pd.Timestamp('2023-12-31 00:00:00'), pd.Timestamp('2024-01-17 00:00:00'), pd.Timestamp('2024-01-19 00:00:00'), pd.Timestamp('2024-01-26 00:00:00'), pd.Timestamp('2024-02-12 00:00:00'), pd.Timestamp('2024-02-20 00:00:00'), pd.Timestamp('2024-03-14 00:00:00'), pd.Timestamp('2024-03-22 00:00:00'), pd.Timestamp('2024-07-11 00:00:00'), pd.Timestamp('2024-07-31 00:00:00'), pd.Timestamp('2024-08-22 00:00:00'), pd.Timestamp('2024-09-22 00:00:00'), pd.Timestamp('2024-10-12 00:00:00'), pd.Timestamp('2024-11-04 00:00:00'), pd.Timestamp('2024-11-14 00:00:00'), pd.Timestamp('2024-11-15 00:00:00'), pd.Timestamp('2024-12-02 00:00:00'), pd.Timestamp('2025-05-28 00:00:00'), pd.Timestamp('2025-07-11 00:00:00'), pd.Timestamp('2025-08-05 00:00:00'), pd.Timestamp('2025-12-02 00:00:00'), pd.Timestamp('2025-12-06 00:00:00'), pd.Timestamp('2026-01-28 00:00:00')]


# Calculate time since start in days (or months if preferred)
tim_failures = [(ts - start_date).days for ts in timestamps]


cum_failures = np.array([286+25,467, 468, 469, 470, 471, 472, 474, 476, 477, 479, 480, 481, 482, 483, 484, 486, 487, 488, 489, 501, 503, 505, 506, 507, 508, 509, 510, 511, 512, 514, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 530, 533, 534, 535, 536, 537, 538, 539, 547, 549, 550, 554, 556, 557, 558, 558, 558, 558, 558, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 570, 571, 573, 574, 575, 576, 577, 578, 579, 585, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 599, 600, 601, 602, 605, 606, 607, 611, 615, 616, 618, 619, 620, 621, 623, 624, 625, 626, 627])


def weibull_cdf(t, N, lam, k):
    return N * (1 - np.exp(-(t/lam)**k))

N_guess = cum_failures[-1]
lam_guess = np.median(durations)
k_guess = 0.5

params, _ = curve_fit(
    weibull_cdf, 
    tim_failures, 
    cum_failures, 
    p0=[N_guess, lam_guess, k_guess]
)

N_hat, lam_hat, k_hat = params
print(f"Best fit: N={N_hat:.2f}, lambda={lam_hat:.2f}, k={k_hat:.2f}")
# Generate smooth time for fitted curve
t_smooth = np.linspace(np.array(tim_failures).min(), np.array(tim_failures).max(), 200)
t_smooth = np.linspace(100, 6000, 200)
weibull_fit = weibull_cdf(t_smooth, N_hat, lam_hat, k_hat)

# Create plot
p = figure(title="Cumulative Failures: Data vs. Weibull Fit",
           x_axis_label='Time (days)',
           y_axis_label='Cumulative Failures',
           width=800, height=400, x_range=(0,6000), y_range=(200,700))

# Data points
p.circle(tim_failures, cum_failures, legend_label="Data", size=8, color="navy")

# Fitted Weibull curve
p.line(t_smooth, weibull_fit, legend_label="Weibull Fit", line_width=3, color="orange")
p.circle(duan_time,duan_num,size=8)
p.legend.location = "top_left"

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p155417">Loading BokehJS ...</span>
#     </div>
# <ipython-input-99-8aef28f56122>:30: RuntimeWarning: invalid value encountered in power
#   return N * (1 - np.exp(-(t/lam)**k))
# Best fit: N=663.46, lambda=642.90, k=0.78
#   <div id="17e37767-ca6c-4743-8281-eeaa963fad0e" data-root-id="p155418" style="display: contents;"></div>
